# %% [markdown]
# # is Node is persend given (x)

# %%
class BinarytreeNode:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
# def printbinaritree(root):
#     if root ==None:
#         return
#     print(root.data)
#     printbinaritree(root.left)
#     printbinaritree(root.right)
    
def printbinaritreedtails(root):
    if root ==None:
        return
    print(root.data,end=":")
    if root.left !=None:
        print("l",root.left.data,end=",")
    if root.right != None:
        print("R",root.right.data,end="")
    print()
    printbinaritreedtails(root.left)
    printbinaritreedtails(root.right)
    
    
# def greaterthanx(root,x):
#     if root==None:
#         return 0
#     leftcount=greaterthanx(root.left,x)
#     rightcount=greaterthanx(root.right,x)
#     count=leftcount+rightcount
    
#     if root.data>x:
#         count +=1
#     return count


def isnodepersent(root,x) :
	#Your code goes here
    if root == None:
        return False
    if root.data == x:
        return True
    
    leftnode =isnodepersent(root.left,x)
    
    rightnode=isnodepersent(root.right,x)
    if leftnode:
        return True
#     return rightnode
    return False
    
    
def treeinput():
    rootdata=int(input())
    if rootdata== -1:
        return None
    root=BinarytreeNode(rootdata)
    lefttree=treeinput()
    righttree=treeinput()
    root.left=lefttree
    root.right=righttree
    return root


def takeInput():
    print("Enter root data")
    rootData = int(input())
    if (rootData == -1):
        return None
    root = BinaryTreeNode(rootData)
    root.left = takeInput()
    root.right = takeInput()
    return root

# %%
root=treeinput()
printbinaritreedtails(root)
# print(changeToDepthTree(root))
isnodepersent(root,10)
# Out:
# 2
# 3
# -1
# -1
# 4
# -1
# -1
# 2:l 3,R 4
# 3:
# 4:
# False

# %% [markdown]
# # print node without sibling

# %%
class BinarytreeNode:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
# def printbinaritree(root):
#     if root ==None:
#         return
#     print(root.data)
#     printbinaritree(root.left)
#     printbinaritree(root.right)
    
def printbinaritreedtails(root):
    if root ==None:
        return
    print(root.data,end=":")
    if root.left !=None:
        print("l",root.left.data,end=",")
    if root.right != None:
        print("R",root.right.data,end="")
    print()
    printbinaritreedtails(root.left)
    printbinaritreedtails(root.right)
    
    
# def greaterthanx(root,x):
#     if root==None:
#         return 0
#     leftcount=greaterthanx(root.left,x)
#     rightcount=greaterthanx(root.right,x)
#     count=leftcount+rightcount
    
#     if root.data>x:
#         count +=1
#     return count


def printNodesWithoutSibling(root) :
	# Your code goes here
    if root==None:
        return

    if root.left !=None and root.right !=None:
        printNodesWithoutSibling(root.left)
        printNodesWithoutSibling(root.right)

    elif root.right !=None:
        print(root.right.data,end=" ")
        
        printNodesWithoutSibling(root.right)
        
    elif root.left !=None:
        print(root.left.data,end=" ")
        printNodesWithoutSibling(root.left)
    
    
def treeinput():
    rootdata=int(input())
    if rootdata== -1:
        return None
    root=BinarytreeNode(rootdata)
    lefttree=treeinput()
    righttree=treeinput()
    root.left=lefttree
    root.right=righttree
    return root


def takeInput():
    print("Enter root data")
    rootData = int(input())
    if (rootData == -1):
        return None
    root = BinaryTreeNode(rootData)
    root.left = takeInput()
    root.right = takeInput()
    return root

# %%
root=treeinput()
printbinaritreedtails(root)
# print(changeToDepthTree(root))
printNodesWithoutSibling(root)
# Out:
# 2
# 4
# 6
# 20
# -1
# -1
# 30
# -1
# -1
# -1
# 5
# -1
# 7
# 80
# -1
# -1
# 90
# -1
# -1
# 2:l 4,R 5
# 4:l 6,
# 6:l 20,R 30
# 20:
# 30:
# 5:R 7
# 7:l 80,R 90
# 80:
# 90:
# 6 7
