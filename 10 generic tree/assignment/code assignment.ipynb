# %% [markdown]
# # sum of all node in bst

# %%
class TreeNode:
    def __init__(self,data):
        self.data=data
        self.children=list()
        
        
def printTreeDetailed(root):
    # not a base case but an edge case
    if root==None:
        return
    print(root.data,":",end="")
    
    for child in root.children:
        print(child.data,",",end="")
        
    print()
    
    for child in root.children:
        printTreeDetailed(child)
        
import queue      
def takeTreeInputlevelwise():
    q = queue.Queue()
    print("Enter root")
    rootData=int(input())
    
    if rootData == -1 :
        return None
    root = TreeNode(rootData) 
    q.put(root)
    while (not q.empty()) :
        currenrNode = q.get()
        print("Enter num of children for",currenrNode.data)
        numchildren=int(input())
        for i in range(numchildren) :
            print("Enter next children for",currenrNode.data)
            childData=int(input())
            child = TreeNode(childData)
            currenrNode.children.append(child)
            q.put(child)
    
    return root
        
        
def takeTreeInput():
    print("Enter root data")
    rootData=int(input())
    if rootData==-1:
        return None
    
    root=TreeNode(rootData)
    print("Enter no of children for", rootData)
    childrenCount=int(input())
    for i in range(childrenCount):
        child=takeTreeInput()
        root.children.append(child)
    return root

def sumOfAllNodes(root) :
    if root==None:
        return 0
    sum=0
    for child in root.children:
        sum= sum+sumOfAllNodes(child)

    return sum+root.data

# %%
root=takeTreeInputlevelwise()
printTreeDetailed(root)

print(sumOfAllNodes(root))
# Out:
# Enter root
# 1
# Enter num of children for 1
# 1
# Enter next children for 1
# 2
# Enter num of children for 2
# 1
# Enter next children for 2
# 3
# Enter num of children for 3
# 1
# Enter next children for 3
# 4
# Enter num of children for 4
# 1
# Enter next children for 4
# 5
# Enter num of children for 5
# 0
# 1 :2 ,
# 2 :3 ,
# 3 :4 ,
# 4 :5 ,
# 5 :
# 15

# %% [markdown]
# # Node With Largest Data

# %%
class TreeNode:
    def __init__(self,data):
        self.data=data
        self.children=list()
        
        
def printTreeDetailed(root):
    # not a base case but an edge case
    if root==None:
        return
    print(root.data,":",end="")
    
    for child in root.children:
        print(child.data,",",end="")
        
    print()
    
    for child in root.children:
        printTreeDetailed(child)
        
import queue      
def takeTreeInputlevelwise():
    q = queue.Queue()
    print("Enter root")
    rootData=int(input())
    
    if rootData == -1 :
        return None
    root = TreeNode(rootData) 
    q.put(root)
    while (not q.empty()) :
        currenrNode = q.get()
        print("Enter num of children for",currenrNode.data)
        numchildren=int(input())
        for i in range(numchildren) :
            print("Enter next children for",currenrNode.data)
            childData=int(input())
            child = TreeNode(childData)
            currenrNode.children.append(child)
            q.put(child)
    
    return root
        
        
def takeTreeInput():
    print("Enter root data")
    rootData=int(input())
    if rootData==-1:
        return None
    
    root=TreeNode(rootData)
    print("Enter no of children for", rootData)
    childrenCount=int(input())
    for i in range(childrenCount):
        child=takeTreeInput()
        root.children.append(child)
    return root

def maxDataNode(tree):
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    # pass
    if tree ==None:
        return None

    maxnode=tree
    for  child in tree.children:
        temp=maxDataNode(child)
        if temp.data>maxnode.data:
            maxnode=temp

    return maxnode



root=takeTreeInputlevelwise()
printTreeDetailed(root)

print(maxDataNode(root).data)
maxDataNode(root).data
# Out:
# Enter root
# 10
# Enter num of children for 10
# 3
# Enter next children for 10
# 20
# Enter next children for 10
# 30
# Enter next children for 10
# 40
# Enter num of children for 20
# 2
# Enter next children for 20
# 40
# Enter next children for 20
# 50
# Enter num of children for 30
# 0
# Enter num of children for 40
# 0
# Enter num of children for 40
# 0
# Enter num of children for 50
# 0
# 10 :20 ,30 ,40 ,
# 20 :40 ,50 ,
# 40 :
# 50 :
# 30 :
# 40 :
# 50
# 50

# %% [markdown]
# # Height Of Tree

# %%
class TreeNode:
    def __init__(self,data):
        self.data=data
        self.children=list()
        
        
def printTreeDetailed(root):
    # not a base case but an edge case
    if root==None:
        return
    print(root.data,":",end="")
    
    for child in root.children:
        print(child.data,",",end="")
        
    print()
    
    for child in root.children:
        printTreeDetailed(child)
        
import queue      
def takeTreeInputlevelwise():
    q = queue.Queue()
    print("Enter root")
    rootData=int(input())
    
    if rootData == -1 :
        return None
    root = TreeNode(rootData) 
    q.put(root)
    while (not q.empty()) :
        currenrNode = q.get()
        print("Enter num of children for",currenrNode.data)
        numchildren=int(input())
        for i in range(numchildren) :
            print("Enter next children for",currenrNode.data)
            childData=int(input())
            child = TreeNode(childData)
            currenrNode.children.append(child)
            q.put(child)
    
    return root
        
        
def takeTreeInput():
    print("Enter root data")
    rootData=int(input())
    if rootData==-1:
        return None
    
    root=TreeNode(rootData)
    print("Enter no of children for", rootData)
    childrenCount=int(input())
    for i in range(childrenCount):
        child=takeTreeInput()
        root.children.append(child)
    return root

def height(root) :
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    # if root==None:
    #     return 0
    # sum=root.data
    # for child in root.children:
    #     sum= sum+sumOfAllNodes(child)

    # return sum

    if root==None:
        return 0
    sum=0
    for child in root.children:
        childheight =height(child)
        if childheight>sum:
            sum=childheight

    return 1+ sum




root=takeTreeInputlevelwise()
printTreeDetailed(root)

print(height(root))
# height(root).data
# Out:
# Enter root
# 10
# Enter num of children for 10
# 3
# Enter next children for 10
# 20
# Enter next children for 10
# 30
# Enter next children for 10
# 40
# Enter num of children for 20
# 2
# Enter next children for 20
# 40
# Enter next children for 20
# 50
# Enter num of children for 30
# 0
# Enter num of children for 40
# 0
# Enter num of children for 40
# 0
# Enter num of children for 50
# 0
# 10 :20 ,30 ,40 ,
# 20 :40 ,50 ,
# 40 :
# 50 :
# 30 :
# 40 :
# 3

# %% [markdown]
# # print levelwise

# %%
class TreeNode:
    def __init__(self,data):
        self.data=data
        self.children=list()
        
        
def printTreeDetailed(root):
    # not a base case but an edge case
    if root==None:
        return
    print(root.data,":",end="")
    
    for child in root.children:
        print(child.data,",",end="")
        
    print()
    
    for child in root.children:
        printTreeDetailed(child)
        
# class treeNode:
#     def __init__(self, data):
#         self.data = data
#         self.children = []
#     def __str__(self):
#         return str(self.data)

def printLevelWiseTrees(tree):
    q = queue.Queue()
    if tree == None:
        return
    q.put(tree)
    
    while (not(q.empty())):
        current_node = q.get()
        print(current_node, ":", end ="")
        for child in current_node.children:
            q.put(child)
            # print(end=",")
            print(child.data,",",end = "")
        print()

def printLevelWiseTree(tree):
    q = [tree]
    while q:
        parent = q.pop(0)
        print(parent.data,':', ",".join(str(num) for num in parent.children),
                sep='')
        for child in parent.children:
            q.append(child)
        
import queue      
def takeTreeInputlevelwise():
    q = queue.Queue()
    print("Enter root")
    rootData=int(input())
    
    if rootData == -1 :
        return None
    root = TreeNode(rootData) 
    q.put(root)
    while (not q.empty()) :
        currenrNode = q.get()
        print("Enter num of children for",currenrNode.data)
        numchildren=int(input())
        for i in range(numchildren) :
            print("Enter next children for",currenrNode.data)
            childData=int(input())
            child = TreeNode(childData)
            currenrNode.children.append(child)
            q.put(child)
    
    return root
        
        
def takeTreeInput():
    print("Enter root data")
    rootData=int(input())
    if rootData==-1:
        return None
    
    root=TreeNode(rootData)
    print("Enter no of children for", rootData)
    childrenCount=int(input())
    for i in range(childrenCount):
        child=takeTreeInput()
        root.children.append(child)
    return root

def height(root) :
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    # if root==None:
    #     return 0
    # sum=root.data
    # for child in root.children:
    #     sum= sum+sumOfAllNodes(child)

    # return sum

    if root==None:
        return 0
    sum=0
    for child in root.children:
        childheight =height(child)
        if childheight>sum:
            sum=childheight

    return 1+ sum




root=takeTreeInputlevelwise()
printTreeDetailed(root)
printLevelWiseTree(root)

printLevelWiseTrees(root)

# print(height(root))
# height(root).data
# Out:
# Enter root
# 10
# Enter num of children for 10
# 3
# Enter next children for 10
# 20
# Enter next children for 10
# 30
# Enter next children for 10
# 40
# Enter num of children for 20
# 2
# Enter next children for 20
# 40
# Enter next children for 20
# 50
# Enter num of children for 30
# 0
# Enter num of children for 40
# 0
# Enter num of children for 40
# 0
# Enter num of children for 50
# 0
# 10 :20 ,30 ,40 ,
# 20 :40 ,50 ,
# 40 :
# 50 :
# 30 :
# 40 :
# 10:<__main__.TreeNode object at 0x000001A41514A080>,<__main__.TreeNode object at 0x000001A415149F30>,<__main__.TreeNode object at 0x000001A41514AF20>
# 20:<__main__.TreeNode object at 0x000001A415149DE0>,<__main__.TreeNode object at 0x000001A415149D80>
# 30:
# 40:
# 40:
# 50:
# <__main__.TreeNode object at 0x000001A413140910> :20 ,30 ,40 ,
# <__main__.TreeNode object at 0x000001A41514A080> :40 ,50 ,
# <__main__.TreeNode object at 0x000001A415149F30> :
# <__main__.TreeNode object at 0x000001A41514AF20> :
# <__main__.TreeNode object at 0x000001A415149DE0> :
# <__main__.TreeNode object at 0x000001A415149D80> :

# %%
class treeNode:
    def __init__(self, data):
        self.data = data
        self.children = []
    def __str__(self):
        return str(self.data)

import queue    
def printLevelWiseTree(tree):
    q = queue.Queue()
    if tree == None:
        return
    q.put(tree)
    
    while (not(q.empty())):
        current_node = q.get()
        print(current_node, ":", end = "")
        for child in current_node.children:
            q.put(child)
            print(child.data, end = ",")
        print()
   
    
    
def takeTreeInputLevelWise():
    q = queue.Queue()
    print("Enter root")
    rootData = int(input())
    if rootData == -1:
        return None
    
    root = TreeNode(rootData)
    q.put(root)
    
    while (not(q.empty())):
        current_node = q.get()
        print("Enter number of childrens for ", current_node.data)
        numChildren = int(input())
        for i in range(numChildren):
            print("Enter next child for ", current_node.data)
            childData = int(input())
            child = TreeNode(childData)
            current_node.children.append(child)
            q.put(child)
            
    return root
    
    
def createLevelWiseTree(arr):
    root = treeNode(int(arr[0]))
    q = [root]
    size = len(arr)
    i = 1
    while i<size:
        parent = q.pop(0)
        childCount = int(arr[i])
        i += 1
        for j in range(0,childCount):
            temp = treeNode(int(arr[i+j]))
            parent.children.append(temp)
            q.append(temp)
        i += childCount
    return root

# Main
arr = list(int(x) for x in input().strip().split(' '))
tree = createLevelWiseTree(arr)
printLevelWiseTree(tree)
# Out:
# 10 3 20 30 40 2 40 50 0 0 0 0
# 10 :20,30,40,
# 20 :40,50,
# 30 :
# 40 :
# 40 :
# 50 :
