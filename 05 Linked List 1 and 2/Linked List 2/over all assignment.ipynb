# %% [markdown]
# # find node LL by recursion

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def findNodeRec(head, n) :
    if head is None :
        return -1
    if head.data==n:
        return 0
    find=findNodeRec(head.next,n)
    if find != -1:
        return 1+find
    else:
        return -1



    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=findNodeRec(head,5)
print(head)
printLL(head)
# Out:
# 1 3 4 5 -1
# 1->3->4->5->None
# 3

# %% [markdown]
# # even After odd

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def evenAfterOdd(head) :
    odd=None
    ot=None
    even=None
    et=None
    curr=head
    while curr is not None:
        if curr.data%2 !=0:
            if odd is None:
                odd=curr
                ot=curr
            else:
                ot.next=curr
                ot=ot.next
        else:
            if even is None:
                even=curr
                et=curr
            else:
                et.next=curr
                et=et.next
        curr=curr.next
    # when fist come even after odd
    # if even:
    #     head=even
    #     et.next=odd
    # else:
    #     head=odd
    #     # ot.next=even
    # if ot:
    #     ot.next=None

    # when fist come odd after even
    if odd:
        head=odd
        ot.next=even
    else:
        head=even
    if et:
        et.next=None
        
    return head
            
    
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=evenAfterOdd(head)
# print(head)
printLL(head)
# Out:
# 1 4 5 2 -1
# 1->4->5->2->None
# 4->2->1->5->None

# %% [markdown]
# # delete every N node

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def deleteeveryNnode(head,m,n):
    curr=head
    if m<=0:
        return
    while curr is not None:
        if m<=0:
            return
        for count in range(1,m):
            if curr is None:
                return
            curr=curr.next
        if curr is None:
            return
        nex=curr.next
        for count in range(1,n+1):
            if nex is None:
                break
#             if nex is not None:
#                 nex.next=None
            nex=nex.next
        curr.next=nex
        curr=nex
    return head

    
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=deleteeveryNnode(head,2,3)
# print(head)
printLL(head)
# Out:
# 10 22 10 26 11 7 8 1 23 5 1 -1
# 10->22->10->26->11->7->8->1->23->5->1->None
# None

# %% [markdown]
# # delete every N node by recursion

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def deleteeveryNnode(head,m,n):

    # base case
    if head is None or head.next is None:
        return head
 
    prev = None
    curr = head
 
    # skip `m` nodes
    for i in range(1, m + 1):
        prev = curr
        curr = curr.next
 
        # return if we have reached end of the list
        if curr is None:
            return head
 
    # delete next `n` nodes
    for i in range(1, n + 1):
        if curr is not None:
            next = curr.next
            curr = next
 
    # link remaining nodes with the last node
    prev.next = curr
 
    # recur for remaining nodes
    deleteeveryNnode(curr, m, n)
 
    return head
 
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=deleteeveryNnode(head,2,3)
# print(head)
printLL(head)
# Out:
# 1 2 3 4 5 6 7 8 -1
# 1->2->3->4->5->6->7->8->None
# 1->2->6->7->None

# %% [markdown]
# # swap two node

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def swapNodes(head_ref, x, y):
    head = head_ref
 
    # Nothing to do if x and y are same
    if (x == y):
        return None
 
    a = None
    b = None
 
    # search for x and y in the linked list
    # and store their pointer in a and b
    count =0
    while (head_ref.next != None):
 
        if ((head_ref.next).data == x):
            a = head_ref
 
        elif ((head_ref.next).data == y):
            b = head_ref
 
        head_ref = ((head_ref).next)
 
    # if we have found both a and b
    # in the linked list swap current
    # pointer and next pointer of these
    if (a != None and b != None):
        temp = a.next
        a.next = b.next
        b.next = temp
        temp = a.next.next
        a.next.next = b.next.next
        b.next.next = temp
 
    return head
 
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=swapNodes(head,10,20)
# print(head)
printLL(head)
# Out:
# 20 10 30 40 5 -1
# 20->10->30->40->5->None
# 20->10->30->40->5->None

# %% [markdown]
# # swap two node by index position

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def swapNodes(head,i,j):
    curr=head
    prev=None
    c1=None
    c2=None
    p1=None
    p2=None
    count=0
    while curr is not  None:

        if(count==i):
            p1=prev
            c1=curr
        elif(count==j):
            p2=prev
            c2=curr

        prev=curr
        curr=curr.next
        count +=1
    if p1 is not None:
        p1.next=c2
    else:
        head=c2
            
    if p2 is not None:
        p2.next=c1
    else:
        head=c1
        
    temp=c2.next
    c2.next=c1.next
    c1.next=temp
    return head
 
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=swapNodes(head,1,2)
# print(head)
printLL(head)
# Out:
# 10 20 30 40 -1
# 10->20->30->40->None
# 10->30->20->40->None

# %% [markdown]
# # K reverse recursion

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def reverse(head, k):
    if k==0 or k==1:
        return head
        
    if head == None:
        return None
    current = head
    next = None
    prev = None
    count = 0
  
        # Reverse first k nodes of the linked list
    while(current is not None and count < k):
        next = current.next
        current.next = prev
        prev = current
        current = next
        count += 1
  
        # next is now a pointer to (k+1)th node
        # recursively call for the list starting
        # from current. And make rest of the list as
        # next of first node
    if next is not None:
        head.next = reverse(next, k)
  
        # prev is new head of the input list
    return prev
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=reverse(head,3)
# print(head)
printLL(head)
# Out:
# 1 2 3 4 5 6 7 8 -1
# 1->2->3->4->5->6->7->8->None
# 3->2->1->6->5->4->8->7->None

# %% [markdown]
# # bubble sort by iterative

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return
def lengthLL(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count
        
def bubleSort(head):
    if(head is None or head.next is None):
        return head
        
    for i in range(0,lengthLL(head)-1):
        prev = None
        curr = head
        next = curr.next

        while(curr.next is not None):
            if(curr.data > curr.next.data):
                if(prev is None):
                    curr.next = next.next
                    next.next = curr
                    prev = next
                    head = prev
                else:
                    next = curr.next
                    curr.next = next.next
                    prev.next = next
                    next.next = curr
                    prev = next
                    
            else:
                prev = curr
                curr = curr.next
                
    return head
    

    
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head
head = takeinput()            
printLL(head)
head=bubleSort(head)
# print(head)
printLL(head)
# Out:
# 10 9 8 7 6 5 4 3 -1
# 10->9->8->7->6->5->4->3->None
# 3->4->5->6->7->8->9->10->None
