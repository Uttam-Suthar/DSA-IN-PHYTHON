# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        
        if currdata== -1:
            break
        newnode = Node(currdata)
        
        if head is None:
            head =newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
      
    return head 

def printLL(head):
    while head is not None:
        print(str(head.data) + "->", end='')
        head=head.next
    print("None")
    return

def length(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count

def findNode(head,n):
    curr=head
    count=0
    while curr is not None:
        if curr.data==n:
            return count
        count=count+1
        curr=curr.next
    
    return -1
#     count = 0
#     curr = head
#     while curr is not None:
#         if curr.data == n:
#             return count
#         count += 1
#         curr = curr.next       
#     return -1
    

head = takeinput()            
printLL(head)
head=findNode(head,4)
print(head)
# Out:
# 1 2 3 4 5 -1
# 1->2->3->4->5->None
# 3

# %% [markdown]
# # append last to first

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def takeInput():
    inputList = [ int(ele) for ele in input().split()]
    head = None
    tail = None
    
    for currData in inputList:
        if currData == -1:
            break
        
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

def printLL(head):
    while head is not None:
        print(str(head.data)+'->',end = '')
        head = head.next
    print('None')
    return

def lengthLL(head):
    count = 0
    curr = head
    while curr is not None:
        count += 1
        curr = curr.next
    return count

def AppendLastN(head, n):
    if n<0 or n>lengthLL(head):
        return None
    if n == 0:
        return head 
    curr = head
    prev = None
    head2 = None
    
   

    len = lengthLL(head)
    count = len - n
    
    i = 0
    while i < count :
        prev = curr
        curr = curr.next
        i += 1
    
    head2 = curr
    prev.next = None
    
    
    
    len2 = lengthLL(head2)
    j = 0
    prev = None
    tail = head2

    while j < len2:
        prev = tail
        tail = tail.next
        j +=1
    prev.next = head
    
    
    return head2
        
head = takeInput()
printLL(head)
head = AppendLastN(head, 7)
printLL(head)
# Out:
# 4 4 7 8 3 36 8 17 26 7 7 -1
# 4->4->7->8->3->36->8->17->26->7->7->None
# 3->36->8->17->26->7->7->4->4->7->8->None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def takeInput():
    inputList = [ int(ele) for ele in input().split()]
    head = None
    tail = None
    
    for currData in inputList:
        if currData == -1:
            break
        
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

def printLL(head):
    while head is not None:
        print(str(head.data)+'->',end = '')
        head = head.next
    print('None')
    return

def length(head):
    cnt = 0
    while head is not None:
        cnt += 1
        head = head.next
    return cnt

def AppendLastN(head, n):
    if n<0 or n>lengthLL(head):
        return None
    if n == 0:
        return head 
    pos = length(head) - n
    curr = head
    prev = head
    
    for i in range(1,pos):
        curr = curr.next
    
    last = curr
    temp = curr.next
    head = temp
    
    while curr.next is not None:
        curr = curr.next
    curr.next = prev
    last.next = None
    
    return head
        
head = takeInput()
printLL(head)
head = AppendLastN(head, 7)
printLL(head)
# Out:
# 4 4 7 8 3 36 8 17 26 7 7 -1
# 4->4->7->8->3->36->8->17->26->7->7->None
# 3->36->8->17->26->7->7->4->4->7->8->None

# %% [markdown]
# # remove duplicate

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def takeInput():
    inputList = [ int(ele) for ele in input().split()]
    head = None
    tail = None
    
    for currData in inputList:
        if currData == -1:
            break
        
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

def printLL(head):
    while head is not None:
        print(str(head.data)+'->',end = '')
        head = head.next
    print('None')
    return

# def lengthLL(head):
#     count = 0
#     curr = head
#     while curr is not None:
#         count += 1
#         curr = curr.next
#     return count

def deleteduplicate(head):
    if head is None or head.next is None:
        return head
    t1=head
    t2=t1.next
    while t2 is not None:
        if t1.data==t2.data:
            t1.next=t2.next
            t2=t1.next
        else:
            t1=t1.next
            t2=t2.next
            
    return head
        
head = takeInput()
printLL(head)
head = deleteduplicate(head)
printLL(head)
# Out:
# 1 2 2 3 3 4 -1
# 1->2->2->3->3->4->None
# 1->2->3->4->None

# %% [markdown]
# # reversed link list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def takeInput():
    inputList = [ int(ele) for ele in input().split()]
    head = None
    tail = None
    
    for currData in inputList:
        if currData == -1:
            break
        
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

def printLL(head):
    while head is not None:
        print(str(head.data)+'->',end = '')
        head = head.next
    print('None')
    return

# def lengthLL(head):
#     count = 0
#     curr = head
#     while curr is not None:
#         count += 1
#         curr = curr.next
#     return count

def reversedlink(head):
    if head is None :
        return head
    smallhead=reversedlink(head.next)
    print(str(head.data), end = ' ')
#     head.next=smallhead
#     return head
        
head = takeInput()
printLL(head)
head = reversedlink(head)
printLL(head)
# Out:
# 1 2 3 4 -1
# 1->2->3->4->None
# 4 3 2 1 None

# %% [markdown]
# # plinrome or not

# %%
def isPalindrome(head):
    arr = []
    while head != None:
        arr.append(head.data)
        head = head.next
    for i in range(len(arr)//2):
        if arr[i] != arr[len(arr)-i-1]:
            return False
    return True

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def takeInput():
    inputList = [ int(ele) for ele in input().split()]
    head = None
    tail = None
    
    for currData in inputList:
        if currData == -1:
            break
        
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

def printLL(head):
    while head is not None:
        print(str(head.data)+'->',end = '')
        head = head.next
    print('None')
    return


def palidromnum(head):
    arr=[]
    while head is not None:
        arr.append(head.data)
        head=head.next
    for i in range(len(arr)//2):
        if arr[i] !=arr[len(arr)-i-1]:
            return False
    else:
        return True

        
head = takeInput()
printLL(head)
head = palidromnum(head)
# printLL(head)
head
# Out:
# 1 2 3 1 -1
# 1->2->3->1->None
# False
