# %%
def checkpermutationcombi(str1,str2):
    
    for i in range(len(str1)):
        j=0
#         flag=False
        while j<=len(str2):
#         for i in range(len(str2)):
#             if str1[i]==str2[j]:
            if chr(ord(str1[i])) != chr(ord(str2[i])):
#                 flag = True
                return False
                    
            
            j=j+1
            
#             if flag:
#                 return True
    return True
        


str1="race"
str2="race"
ans= checkpermutationcombi(str1,str2)
if ans:
    print("true")
else:
    print("false")
# Out:
# true

# %%
def isPermutation(string1, string2) :
	#Your code goes here
    if len(string1) != len(string2):
         return False                    
    for i in range(len(string1)):
        flag = False
        for j in range(len(string2)):
            if string1[i] == string2[j]:
                flag = True
                break
        if not(flag):
            return False
    return True
# str1="listen"
# str2="silent"
str1="racee"
str2="racer"
ans= isPermutation(str1,str2)
if ans:
    print("true")
else:
    print("false")
# Out:
# true

# %%
def isPermutation(string1, string2) :
	#Your code goes here
  
    for i in range(len(string1)):
#         start=0
#         end = len(string2)-1
        for j in range(len(string2)-1):
            # if string1[i]==string2[j]:
            if ord(string1[i]) !=ord(string2[j]):
                return True
    else:
        return False
str1="listen"
str2="silent"
ans= checkpermutationcombi(str1,str2)
if ans:
    print("true")
else:
    print("false")
# Out:
# false

# %%
def checkpermutationcombi(str1,str2):
    
    for i in range(len(str1)):
        start=0
        end= len(str2)-1
#         flag=False
        while start<end:
#         for i in range(len(str2)):
#             if str1[i]==str2[j]:
            if ord(str1[i]) !=ord(str2[start]):
                return False

            else:
                start += 1
                end -= 1
           
    return True
  
        


str1="race"
str2="rate"
ans= checkpermutationcombi(str1,str2)
if ans:
    print("true")
else:
    print("false")
# Out:
# false

# %%
def checkpermutationcombi(str1,str2):
    for i in range(len(str1)):
        start=0
        end=len(str2)-1
        while start<end:
            if str1[i] !=str2[end]:
                return False
                start +=1
                end -=1
            else:
                return True
           
    return False
  
        


str1="race"
str2="race"
ans= checkpermutationcombi(str1,str2)
if ans:
    print("true")
else:
    print("false")
# Out:
# false

# %%
n = int(input())
i = n
while i <= n:
    spaces = 1
    while spaces <= n -1:
        print (" ", end=' ')
        spaces = spaces = +1
    j = 1
    p = i
    while j <= i:
        print(p , end=' ')
        p = p + 1
# Out:
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 spaces = 1
#       5 while spaces <= n -1:
# ----> 6     print (" ", end=' ')
#       7     spaces = spaces = +1
#       8 j = 1
#
# KeyboardInterrupt:
